# %%
import pandas as pd

url = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_1%20.csv"
url2 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_2.csv"
url3 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_3.csv"
url4 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_4.csv"

tienda = pd.read_csv(url)
tienda2 = pd.read_csv(url2)
tienda3 = pd.read_csv(url3)
tienda4 = pd.read_csv(url4)

tienda.head()
# Out:
#             Producto Categoría del Producto    Precio  Costo de envío  \
# 0  Asistente virtual           Electrónicos  164300.0          6900.0
# 1    Mesa de comedor                Muebles  192300.0          8400.0
# 2      Juego de mesa               Juguetes  209600.0         15900.0
# 3         Microondas      Electrodomésticos  757500.0         41000.0
# 4   Silla de oficina                Muebles  335200.0         20200.0
#
#   Fecha de Compra         Vendedor Lugar de Compra  Calificación  \
# 0      16/01/2021      Pedro Gomez          Bogotá             4
# 1      18/05/2022  Beatriz Morales        Medellín             1
# 2      15/03/2021   Juan Fernandez       Cartagena             1
# 3      03/05/2022   Juan Fernandez            Cali             4
# 4      07/11/2020    Maria Alfonso        Medellín             5
#
#        Método de pago  Cantidad de cuotas       lat       lon
# 0  Tarjeta de crédito                   8   4.60971 -74.08175
# ...

# %% [markdown]
# # **1. Análisis de facturación**

# %%
Preio = tienda['Precio'].sum(numeric_only=True)
Preio2 = tienda2['Precio'].sum(numeric_only=True)
Preio3 = tienda3['Precio'].sum(numeric_only=True)
Preio4 = tienda4['Precio'].sum(numeric_only=True)

# %%
Precios = {"Tienda": ['Tienda 1', 'Tienda 2','Tienda 3','Tienda 4'], "Ingresos totales": [Preio, Preio2, Preio3, Preio4]}
TablaPrecio = pd.DataFrame(data=Precios)
TablaPrecio
# Out:
#      Tienda  Ingresos totales
# 0  Tienda 1      1.150880e+09
# 1  Tienda 2      1.116344e+09
# 2  Tienda 3      1.098020e+09
# 3  Tienda 4      1.038376e+09

# %%
TablaPrecio.plot(kind='barh',y='Ingresos totales',x='Tienda',figsize=(12,8))
# Out:
# <Axes: ylabel='Tienda'>

# %% [markdown]
# ## 1.1. Análisis de facturación tienda 1

# %%
CategoriaPrecios = tienda.groupby('Categoría del Producto')['Precio'].sum(numeric_only=True)
CategoriaPrecios
# Out:
# Categoría del Producto
# Artículos para el hogar     12698400.0
# Deportes y diversión        39290000.0
# Electrodomésticos          363685200.0
# Electrónicos               429493500.0
# Instrumentos musicales      91299000.0
# Juguetes                    17995700.0
# Libros                       8784900.0
# Muebles                    187633700.0
# Name: Precio, dtype: float64

# %%
CategoriaPrecios.plot(kind='pie',figsize=(12,8), legend=bool)
# Out:
# <Axes: ylabel='Precio'>

# %% [markdown]
# ## 1.2. Análisis de facturación tienda 2

# %%
CategoriaPrecios2 = tienda2.groupby('Categoría del Producto')['Precio'].sum(numeric_only=True)
CategoriaPrecios
# Out:
# Categoría del Producto
# Artículos para el hogar     12698400.0
# Deportes y diversión        39290000.0
# Electrodomésticos          363685200.0
# Electrónicos               429493500.0
# Instrumentos musicales      91299000.0
# Juguetes                    17995700.0
# Libros                       8784900.0
# Muebles                    187633700.0
# Name: Precio, dtype: float64

# %%
CategoriaPrecios2.plot(kind='pie',figsize=(12,8), legend=bool)
# Out:
# <Axes: ylabel='Precio'>

# %% [markdown]
# ## 1.3. Análisis de facturación tienda 3

# %%
CategoriaPrecios3 = tienda3.groupby('Categoría del Producto')['Precio'].sum(numeric_only=True)
CategoriaPrecios
# Out:
# Categoría del Producto
# Artículos para el hogar     12698400.0
# Deportes y diversión        39290000.0
# Electrodomésticos          363685200.0
# Electrónicos               429493500.0
# Instrumentos musicales      91299000.0
# Juguetes                    17995700.0
# Libros                       8784900.0
# Muebles                    187633700.0
# Name: Precio, dtype: float64

# %%
CategoriaPrecios3.plot(kind='pie',figsize=(12,8), legend=bool)
# Out:
# <Axes: ylabel='Precio'>

# %% [markdown]
# ## 1.4. Análisis de facturación tienda 4

# %%
CategoriaPrecios4 = tienda4.groupby('Categoría del Producto')['Precio'].sum(numeric_only=True)
CategoriaPrecios
# Out:
# Categoría del Producto
# Artículos para el hogar     12698400.0
# Deportes y diversión        39290000.0
# Electrodomésticos          363685200.0
# Electrónicos               429493500.0
# Instrumentos musicales      91299000.0
# Juguetes                    17995700.0
# Libros                       8784900.0
# Muebles                    187633700.0
# Name: Precio, dtype: float64

# %%
CategoriaPrecios4.plot(kind='pie',figsize=(12,8), legend=bool)
# Out:
# <Axes: ylabel='Precio'>

# %% [markdown]
# # **2. Ventas por categoría**

# %%
CantidadCategoria = tienda['Categoría del Producto'].value_counts()
CantidadCategoria2 = tienda2['Categoría del Producto'].value_counts()
CantidadCategoria3 = tienda3['Categoría del Producto'].value_counts()
CantidadCategoria4 = tienda4['Categoría del Producto'].value_counts()

# %% [markdown]
# Ventas totales por categoria

# %%
Conteo = (tienda['Categoría del Producto'].value_counts())+(tienda2['Categoría del Producto'].value_counts())+(tienda3['Categoría del Producto'].value_counts())+(tienda4['Categoría del Producto'].value_counts())
Conteo.sort_values(ascending=False)
# Out:
# Categoría del Producto
# Muebles                    1886
# Electrónicos               1772
# Juguetes                   1290
# Electrodomésticos          1149
# Deportes y diversión       1113
# Instrumentos musicales      753
# Libros                      742
# Artículos para el hogar     730
# Name: count, dtype: int64

# %%
Conteo.sort_values(ascending=True).plot(kind='barh',figsize=(12,8))
# Out:
# <Axes: ylabel='Categoría del Producto'>

# %% [markdown]
# ## 2.1. Ventas por categoría tienda 1

# %%
CantidadCategoria
# Out:
# Categoría del Producto
# Muebles                    465
# Electrónicos               448
# Juguetes                   324
# Electrodomésticos          312
# Deportes y diversión       284
# Instrumentos musicales     182
# Libros                     173
# Artículos para el hogar    171
# Name: count, dtype: int64

# %%
CantidadCategoria.sort_values(ascending=True).plot(kind='barh',figsize=(12,8))
# Out:
# <Axes: ylabel='Categoría del Producto'>

# %% [markdown]
# ## 2.2. Ventas por categoría tienda 2

# %%
CantidadCategoria2
# Out:
# Categoría del Producto
# Muebles                    442
# Electrónicos               422
# Juguetes                   313
# Electrodomésticos          305
# Deportes y diversión       275
# Instrumentos musicales     224
# Libros                     197
# Artículos para el hogar    181
# Name: count, dtype: int64

# %%
CantidadCategoria2.plot(kind='barh',figsize=(12,8))
# Out:
# <Axes: ylabel='Categoría del Producto'>

# %% [markdown]
# ## 2.3. Ventas por categoría tienda 3

# %%
CantidadCategoria3
# Out:
# Categoría del Producto
# Muebles                    499
# Electrónicos               451
# Juguetes                   315
# Electrodomésticos          278
# Deportes y diversión       277
# Libros                     185
# Instrumentos musicales     177
# Artículos para el hogar    177
# Name: count, dtype: int64

# %%
CantidadCategoria3.plot(kind='barh',figsize=(12,8))
# Out:
# <Axes: ylabel='Categoría del Producto'>

# %% [markdown]
# ## 2.4. Ventas por categoría tienda 4

# %%
CantidadCategoria4
# Out:
# Categoría del Producto
# Muebles                    480
# Electrónicos               451
# Juguetes                   338
# Deportes y diversión       277
# Electrodomésticos          254
# Artículos para el hogar    201
# Libros                     187
# Instrumentos musicales     170
# Name: count, dtype: int64

# %%
CantidadCategoria4.plot(kind='barh',figsize=(12,8))
# Out:
# <Axes: ylabel='Categoría del Producto'>

# %% [markdown]
# # **3. Calificación promedio de la tienda**

# %%
CalificacionCategoria = tienda.groupby('Categoría del Producto')['Calificación'].mean(numeric_only=True)
CalificacionCategoria2 = tienda2.groupby('Categoría del Producto')['Calificación'].mean(numeric_only=True)
CalificacionCategoria3 = tienda3.groupby('Categoría del Producto')['Calificación'].mean(numeric_only=True)
CalificacionCategoria4 = tienda4.groupby('Categoría del Producto')['Calificación'].mean(numeric_only=True)

# %% [markdown]
# Valoracion global

# %%
PromedioGlobal = ((tienda.groupby('Categoría del Producto')['Calificación'].mean(numeric_only=True))+(tienda2.groupby('Categoría del Producto')['Calificación'].mean(numeric_only=True))+(tienda3.groupby('Categoría del Producto')['Calificación'].mean(numeric_only=True))+(tienda4.groupby('Categoría del Producto')['Calificación'].mean(numeric_only=True)))/4
PromedioGlobal.sort_values(ascending=False)
# Out:
# Categoría del Producto
# Juguetes                   4.071928
# Muebles                    4.033777
# Electrodomésticos          4.011027
# Libros                     4.004387
# Instrumentos musicales     4.000645
# Electrónicos               3.992344
# Deportes y diversión       3.989030
# Artículos para el hogar    3.975939
# Name: Calificación, dtype: float64

# %%
PromedioGlobal.plot(kind='line',figsize=(16,8))
# Out:
# <Axes: xlabel='Categoría del Producto'>

# %% [markdown]
# ## 3.1. Calificación promedio de la tienda 1

# %%
CalificacionCategoria.sort_values(ascending=False)
# Out:
# Categoría del Producto
# Juguetes                   4.077160
# Instrumentos musicales     4.049451
# Electrodomésticos          4.032051
# Electrónicos               4.004464
# Libros                     3.976879
# Muebles                    3.946237
# Deportes y diversión       3.897887
# Artículos para el hogar    3.748538
# Name: Calificación, dtype: float64

# %%
CalificacionCategoria.plot(kind='line',figsize=(16,10),)
# Out:
# <Axes: xlabel='Categoría del Producto'>

# %% [markdown]
# ## 3.2. Calificación promedio de la tienda 2

# %%
CalificacionCategoria2.sort_values(ascending=False)
# Out:
# Categoría del Producto
# Muebles                    4.092760
# Electrodomésticos          4.072131
# Artículos para el hogar    4.071823
# Deportes y diversión       4.065455
# Instrumentos musicales     4.035714
# Juguetes                   4.025559
# Electrónicos               3.971564
# Libros                     3.949239
# Name: Calificación, dtype: float64

# %%
CalificacionCategoria2.plot(kind='line',figsize=(16,10),)
# Out:
# <Axes: xlabel='Categoría del Producto'>

# %% [markdown]
# ## 3.3. Calificación promedio de la tienda 3

# %%
CalificacionCategoria3.sort_values(ascending=False)
# Out:
# Categoría del Producto
# Juguetes                   4.196825
# Muebles                    4.098196
# Artículos para el hogar    4.073446
# Libros                     4.048649
# Electrodomésticos          4.010791
# Instrumentos musicales     4.005650
# Electrónicos               3.986696
# Deportes y diversión       3.938628
# Name: Calificación, dtype: float64

# %%
CalificacionCategoria3.plot(kind='line',figsize=(16,10),)
# Out:
# <Axes: xlabel='Categoría del Producto'>

# %% [markdown]
# ## 3.4. Calificación promedio de la tienda 4

# %%
CalificacionCategoria4.sort_values(ascending=False)
# Out:
# Categoría del Producto
# Deportes y diversión       4.054152
# Libros                     4.042781
# Artículos para el hogar    4.009950
# Electrónicos               4.006652
# Muebles                    3.997917
# Juguetes                   3.988166
# Electrodomésticos          3.929134
# Instrumentos musicales     3.911765
# Name: Calificación, dtype: float64

# %%
CalificacionCategoria4.plot(kind='line',figsize=(16,10),)
# Out:
# <Axes: xlabel='Categoría del Producto'>

# %% [markdown]
# # **4. Productos más y menos vendidos**

# %%
CantidadProducto = tienda['Producto'].value_counts()
CantidadProducto2 = tienda2['Producto'].value_counts()
CantidadProducto3 = tienda3['Producto'].value_counts()
CantidadProducto4 = tienda4['Producto'].value_counts()

# %% [markdown]
# Ventas Globales de Productos

# %%
ConteoP = (tienda['Producto'].value_counts())+(tienda2['Producto'].value_counts())+(tienda3['Producto'].value_counts())+(tienda4['Producto'].value_counts())
ConteoP.sort_values(ascending=False)
# Out:
# Producto
# Mesa de noche                  210
# Microondas                     206
# Carrito de control remoto      206
# Batería                        203
# Cama king                      201
# Modelado predictivo            200
# Secadora de ropa               200
# Set de ollas                   200
# Cama box                       199
# Bloques de construcción        199
# Iphone 15                      198
# Armario                        197
# Pandereta                      197
# Balón de baloncesto            197
# Bicicleta                      196
# Iniciando en programación      195
# Smart TV                       192
# Refrigerador                   191
# Cubertería                     189
# Lavavajillas                   189
# Impresora                      188
# Guitarra acústica              188
# Kit de bancas                  188
# Vaso térmico                   187
# TV LED UHD 4K                  187
# Estufa                         187
# ...

# %%
ConteoP.sort_values(ascending=True).plot(kind='barh',figsize=(20,10))
# Out:
# <Axes: ylabel='Producto'>

# %% [markdown]
# ## 4.1. Productos más y menos vendidos de tienda 1

# %% [markdown]
# Los productos mas vendidos son el Microondas, la TV LED UHD 4K y el Armario

# %% [markdown]
# Los productos menos vendidos son los Auriculares con micrófono y el Celular ABXY

# %%
CantidadProducto
# Out:
# Producto
# Microondas                     60
# TV LED UHD 4K                  60
# Armario                        60
# Secadora de ropa               58
# Mesa de noche                  56
# Bloques de construcción        56
# Balón de baloncesto            55
# Bicicleta                      54
# Vaso térmico                   54
# Refrigerador                   54
# Impresora                      54
# Batería                        53
# Cubertería                     52
# Carrito de control remoto      52
# Modelado predictivo            51
# Auriculares                    50
# Ajedrez de madera              49
# Iphone 15                      49
# Lavavajillas                   48
# Lavadora de ropa               47
# Guitarra eléctrica             47
# Guitarra acústica              46
# Sofá reclinable                46
# Silla de oficina               46
# Estufa                         45
# Cama box                       44
# Kit de bancas                  44
# ...

# %%
CantidadProducto.plot(kind='barh',figsize=(12,8))
# Out:
# <Axes: ylabel='Producto'>

# %% [markdown]
# ## 4.2. Productos más y menos vendidos de tienda 2

# %% [markdown]
# EL producto mas vendido es el Iniciando en programación

# %% [markdown]
# EL producto menos vendido es el juego de mesa

# %%
CantidadProducto2
# Out:
# Producto
# Iniciando en programación      65
# Microondas                     62
# Batería                        61
# Guitarra acústica              58
# Pandereta                      58
# Secadora de ropa               57
# Iphone 15                      55
# Bloques de construcción        54
# Armario                        54
# Set de ollas                   52
# Cuerda para saltar             50
# Lavadora de ropa               49
# Silla de oficina               49
# Refrigerador                   49
# Muñeca bebé                    48
# Carrito de control remoto      47
# Guitarra eléctrica             47
# Cama box                       47
# Vaso térmico                   47
# Modelado predictivo            46
# Balón de voleibol              46
# Set de vasos                   46
# Lavavajillas                   46
# Kit de bancas                  45
# Cama king                      45
# Bicicleta                      45
# Mochila                        45
# ...

# %%
CantidadProducto2.plot(kind='barh',figsize=(12,8))
# Out:
# <Axes: ylabel='Producto'>

# %% [markdown]
# ## 4.3. Productos más y menos vendidos de tienda 3

# %% [markdown]
# El producto mas vendido es el Kit de bancas

# %% [markdown]
# El producto menos vendido son los Bloques de construcción

# %%
CantidadProducto3
# Out:
# Producto
# Kit de bancas                  57
# Mesa de comedor                56
# Cama king                      56
# Set de ollas                   55
# Mesa de noche                  55
# Smart TV                       54
# Estufa                         53
# Cuerda para saltar             53
# Modelado predictivo            53
# Carrito de control remoto      52
# Lavavajillas                   52
# Bicicleta                      52
# Juego de mesa                  52
# Pandereta                      51
# Impresora                      50
# Refrigerador                   50
# Balón de baloncesto            50
# Armario                        49
# Balón de voleibol              48
# Tablet ABXY                    48
# Sillón                         47
# Guitarra acústica              47
# Olla de presión                47
# Ajedrez de madera              47
# Ciencia de datos con Python    46
# Iphone 15                      46
# Dinosaurio Rex                 46
# ...

# %%
CantidadProducto3.plot(kind='barh',figsize=(12,8))
# Out:
# <Axes: ylabel='Producto'>

# %% [markdown]
# ## 4.4. Productos más y menos vendidos de tienda 4

# %% [markdown]
# EL producto mas vendido es la cama box

# %% [markdown]
# El producto menos vedido es la Guitarra eléctrica

# %%
CantidadProducto4
# Out:
# Producto
# Cama box                       62
# Cubertería                     59
# Dashboards con Power BI        56
# Cama king                      56
# Carrito de control remoto      55
# Mesa de comedor                55
# Mesa de noche                  55
# Smart TV                       54
# Bloques de construcción        54
# Pandereta                      52
# Impresora                      50
# Modelado predictivo            50
# Asistente virtual              50
# Set de ollas                   50
# Balón de baloncesto            50
# Vaso térmico                   48
# Iphone 15                      48
# Muñeca bebé                    48
# Batería                        48
# Balón de voleibol              48
# Juego de mesa                  48
# Microondas                     48
# Estufa                         47
# Cubo mágico 8x8                47
# Sofá reclinable                47
# Dinosaurio Rex                 47
# Olla de presión                46
# ...

# %%
CantidadProducto4.plot(kind='barh',figsize=(12,8))
# Out:
# <Axes: ylabel='Producto'>

# %% [markdown]
# # **5. Envío promedio por tienda**

# %%
PrecioEnvio = tienda['Costo de envío'].mean(numeric_only=True)
PrecioEnvio2 = tienda2['Costo de envío'].mean(numeric_only=True)
PrecioEnvio3 = tienda3['Costo de envío'].mean(numeric_only=True)
PrecioEnvio4 = tienda4['Costo de envío'].mean(numeric_only=True)

# %% [markdown]
# Costos globales

# %%
PromedioPreciosGlobal = ((tienda['Costo de envío'].mean(numeric_only=True))+(tienda2['Costo de envío'].mean(numeric_only=True))+(tienda3['Costo de envío'].mean(numeric_only=True))+(tienda4['Costo de envío'].mean(numeric_only=True)))/4
f'El promedio general de costos es de {PromedioPreciosGlobal}'
# Out:
# 'El promedio general de costos es de 24874.99570338778'

# %% [markdown]
# ## 5.1. Envío promedio de Tienda 1

# %%
f'El costos promedio de envio de la tienda es de {PrecioEnvio}'
# Out:
# 'El costos promedio de envio de la tienda es de 26018.60958033065'

# %% [markdown]
# ## 5.2. Envío promedio de Tienda 2

# %%
f'El costos promedio de envio de la tienda es de {PrecioEnvio2}'
# Out:
# 'El costos promedio de envio de la tienda es de 25216.235693090293'

# %% [markdown]
# ## 5.3. Envío promedio de Tienda 3

# %%
f'El costos promedio de envio de la tienda es de {PrecioEnvio3}'
# Out:
# 'El costos promedio de envio de la tienda es de 24805.680373039424'

# %% [markdown]
# ## 5.4. Envío promedio de Tienda 4

# %%
f'El costos promedio de envio de la tienda es de {PrecioEnvio4}'
# Out:
# 'El costos promedio de envio de la tienda es de 23459.457167090754'

# %% [markdown]
# # **Analisis**

# %% [markdown]
# La Tienda 4 presenta el desempeño más bajo en comparación con las demás sucursales, lo que justifica su posible venta. Esta tienda genera menores ingresos totales y registra un volumen de ventas inferior, lo que reduce su contribución a la utilidad global de la empresa. Además, al mantener una unidad con menor rendimiento, se destinan recursos operativos, administrativos y logísticos que podrían utilizarse de manera más eficiente en las tiendas con mejor desempeño. Desde desde una perspectiva de gestión, se debe concentrar la inversión y los esfuerzos en las unidades más rentables permite mejorar la eficiencia operativa, incrementar la rentabilidad general del negocio y optimizar la asignación de recursos, por lo que la venta de la Tienda 4 se presenta como una decisión estratégica que favorece la estabilidad y el crecimiento de la empresa.
